# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from tqdm import tqdm
import sklearn
import torch

# %%
from engine import wiener, stocks, get_section

# %%
# Генерируем Винеровский процесс и строим график
Wiener = wiener(t)
print(len(t), len(Wiener))
plt.plot(t, Wiener);
# Out:
# 10000 10000

# %%
# Генерируем цену акции и строим график
S = stocks(wiener(t), 1/8, 1/2)
plt.plot(t, S);

# %%
# Строим график среза в момент времени N
section = get_section()
plt.hist(section, bins='stone');
# Out:
# 100%|██████████| 1000000/1000000 [04:15<00:00, 3917.32it/s]

# %%
# Проверяем, что дисперсия примерно равна N
int(np.var(section)*t_max), N
# Out:
# (4994, 5000)
